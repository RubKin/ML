# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.combine import SMOTEENN

from sklearn.preprocessing import OneHotEncoder, LabelEncoder

plt.rcParams['figure.figsize'] = (14, 12)


import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/churn_modeling_clean.csv", index_col=[0])

# %%
df
# Out:
#             creditscore geography  gender  age  tenure    balance  \
# CustomerId
# 15634602            619    France  Female   42       2       0.00
# 15647311            608     Spain  Female   41       1   83807.86
# 15619304            502    France  Female   42       8  159660.80
# 15701354            699    France  Female   39       1       0.00
# 15737888            850     Spain  Female   43       2  125510.82
# ...                 ...       ...     ...  ...     ...        ...
# 15606229            771    France    Male   39       5       0.00
# 15569892            516    France    Male   35      10   57369.61
# 15584532            709    France  Female   36       7       0.00
# 15682355            772   Germany    Male   42       3   75075.31
# 15628319            792    France  Female   28       4  130142.79
#
#             numofproducts  hascrcard  isactivemember  estimatedsalary  exited
# CustomerId
# ...

# %%
#df = pd.get_dummies(df, drop_first=True)

# %%
df
# Out:
#             creditscore geography  gender  age  tenure    balance  \
# CustomerId
# 15634602            619    France  Female   42       2       0.00
# 15647311            608     Spain  Female   41       1   83807.86
# 15619304            502    France  Female   42       8  159660.80
# 15701354            699    France  Female   39       1       0.00
# 15737888            850     Spain  Female   43       2  125510.82
# ...                 ...       ...     ...  ...     ...        ...
# 15606229            771    France    Male   39       5       0.00
# 15569892            516    France    Male   35      10   57369.61
# 15584532            709    France  Female   36       7       0.00
# 15682355            772   Germany    Male   42       3   75075.31
# 15628319            792    France  Female   28       4  130142.79
#
#             numofproducts  hascrcard  isactivemember  estimatedsalary  exited
# CustomerId
# ...

# %% [markdown]
# ## OnehotEnconding

# %%
df_sample = df[["numofproducts", "hascrcard", "isactivemember", "geography", "gender"]]
df_sample
# Out:
#             numofproducts  hascrcard  isactivemember geography  gender
# CustomerId
# 15634602                1          1               1    France  Female
# 15647311                1          0               1     Spain  Female
# 15619304                3          1               0    France  Female
# 15701354                2          0               0    France  Female
# 15737888                1          1               1     Spain  Female
# ...                   ...        ...             ...       ...     ...
# 15606229                2          1               0    France    Male
# 15569892                1          1               1    France    Male
# 15584532                1          0               1    France  Female
# 15682355                2          1               0   Germany    Male
# 15628319                1          1               0    France  Female
#
# [10000 rows x 5 columns]

# %%
# categorical_cols = ["numofproducts", "hascrcard", "isactivemember", "geography", "gender"]

# le = LabelEncoder()

# df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))    

# ohe = OneHotEncoder()

# array_hot_encoded = ohe.fit_transform(df[categorical_cols])

# data_hot_encoded = pd.DataFrame(array_hot_encoded, index=df.index)

# #Extract only the columns that didnt need to be encoded
# data_other_cols = df.drop(columns=categorical_cols)

# #Concatenate the two dataframes : 
# data_out = pd.concat([data_hot_encoded, data_other_cols], axis=1)

# %%
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df.to_csv("data/chrun_modeling_fe.csv")
